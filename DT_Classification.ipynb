# %% [markdown]
# <a href="https://colab.research.google.com/github/NithyaNachiyar/Machine-Learning-Classification/blob/main/DT_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset=pd.read_csv('Social_Network_Ads.csv')

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
dataset.columns
# Out:
# Index(['User ID', 'Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
dataset['Purchased'].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
indep=dataset[[ 'Age', 'EstimatedSalary', 'Gender_Male']]
dep=dataset[['Purchased']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test= train_test_split(indep, dep, test_size=0.30, random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier=DecisionTreeClassifier(criterion='entropy', random_state=0)
classifier.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred=classifier.predict(X_test)

# %%
print(Y_train)
# Out:
#      Purchased
# 92           0
# 223          1
# 234          0
# 232          1
# 377          0
# ..         ...
# 323          1
# 192          0
# 117          0
# 47           0
# 172          0
#
# [280 rows x 1 columns]

# %%
print(Y_test)
# Out:
#      Purchased
# 132          0
# 309          0
# 341          0
# 196          0
# 246          0
# ..         ...
# 216          0
# 259          1
# 49           0
# 238          0
# 343          1
#
# [120 rows x 1 columns]

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test, y_pred)

# %%
print(cm)
# Out:
# [[71  8]
#  [ 3 38]]

# %%
from sklearn.metrics import classification_report
clf=classification_report(Y_test, y_pred)

# %%
print(clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93        79
#            1       0.83      0.93      0.87        41
#
#     accuracy                           0.91       120
#    macro avg       0.89      0.91      0.90       120
# weighted avg       0.91      0.91      0.91       120
